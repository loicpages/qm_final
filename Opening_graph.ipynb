# %% [markdown]
# <a href="https://colab.research.google.com/github/loicpages/qm_final/blob/main/Opening_graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import plotly.express as px

# %%
data_path = '/content/df_final_use.csv' 
frame = pd.read_csv(data_path)
frame

# %%
fig = px.line(new_frame, x = 'Year', y = 'Food Availibility per capita (kg/cap/year)',
              color = 'Region', line_group = 'Country',
              labels={"Food Availibility per capita (kg/cap/year)": "Food Availibility per capita (kg/cap/year)", "Country": "Country"},
              title = 'Countries: Food Availibility per capita (kg/cap/year)',
              hover_name = 'Country',
              )

fig.for_each_trace(lambda t: t.update(name=t.name.replace("Country=", "")))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="78475c7d-0bb6-4961-acc7-7a67aacd9ffb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("78475c7d-0bb6-4961-acc7-7a67aacd9ffb")) {
#                     Plotly.newPlot(
#                         '78475c7d-0bb6-4961-acc7-7a67aacd9ffb',
# ...
